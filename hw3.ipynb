# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# # 1. Leibniz Pi formula

# %% [markdown]
# $$\begin{align}
# \frac{\pi}{4} = \frac{1}{1}-\frac{1}{3}+\frac{1}{5} -\frac{1}{7} + \frac{1}{9} - \cdots
# \end{align}$$
# 이 식은 라이프니츠의 파이 공식이다.
#
# 1. 다음의 식을 구현하는 함수를 만들어라.
# $$\begin{align}
# f(n) = \frac{1}{1}-\frac{1}{3}+\frac{1}{5} -\frac{1}{7} + \frac{1}{9} - \cdots + \frac{1}{n}.
# \end{align}$$
# 2. 이 식을 이용하여 문제와 같이 그림을 그려라

# %%
def f(n):
    f = 0
    for s in range(1,n+1):
        f = f + ((-1)**(s+1))*1/(2*s-1)
    return f

# %%
a = [f(n) for n in range (1,101)]
plt.plot(a,color='black',label='Leibniz Pi',linewidth=1)
plt.hlines(np.pi/4,0,100,color='pink',label='π/4',linewidth=2)
plt.legend()
plt.grid()

# %% [markdown]
# # 2. Logistic Map
# 로지스틱 맵은 다음처럼 주어진다.$$ f_{n+1} = r f_n (1- f_n). $$
#
# $f_n$을 구하는 함수를 작성하여라.
# 작성한 함수를 이용하여 다음의 조건에서 $n=1$에서 $100$까지 로지스틱 맵의 값을 구하고 그래프로 그려라. 즉, x축은 $n$, y축은 $f_n$인 그래프를 그려라.

# %% [markdown]
# $r=0.5$, $f_0$=0.5,
# $r=0.95$, $f_0$=0.5,
# $r=2$, $f_0$=0.5,
# $r=3.2$, $f_0$=0.5,
# $r=3.8$, $f_0$=0.5,
# $r=3.8$, $f_0$=0.501

# %%
def LogisticMap(r,f):
    for i in range(100):
        f = r*f*(1-f)
        print('f', i+1, '=', f)

# %%
LogisticMap(0.5,0.5)
LogisticMap(0.95,0.5)
LogisticMap(2,0.5)
LogisticMap(3.2,0.5)
LogisticMap(3.8,0.5)
LogisticMap(3.8,0.501)
# Out:
# f 1 = 0.125
# f 2 = 0.0546875
# f 3 = 0.025848388671875
# f 4 = 0.012590124737471342
# f 5 = 0.006215806748283127
# f 6 = 0.0030885852473755623
# f 7 = 0.0015395229442726282
# f 8 = 0.0007685764066883431
# f 9 = 0.00038399284849771257
# f 10 = 0.0001919226989950076
# f 11 = 9.594293233630902e-05
# f 12 = 4.7966863645021866e-05
# f 13 = 2.3982281412506963e-05
# f 14 = 1.1990853131342606e-05
# f 15 = 5.9953546753918944e-06
# f 16 = 2.9976593655571054e-06
# f 17 = 1.4988251897977167e-06
# f 18 = 7.494114716603835e-07
# f 19 = 3.747054550214148e-07
# f 20 = 1.873526573086184e-07
# f 21 = 9.36763111038001e-08
# f 22 = 4.683815116427442e-08
# f 23 = 2.341907448523101e-08
# f 24 = 1.170953696838898e-08
# f 25 = 5.854768415637862e-09
# f 26 = 2.9273841906797743e-09
# f 27 = 1.463692091055098e-09
# f 28 = 7.318460444563517e-10
# f 29 = 3.6592302196037656e-10
# f 30 = 1.8296151091323845e-10
# f 31 = 9.148075543988177e-11
# f 32 = 4.574037771575652e-11
# f 33 = 2.2870188856832168e-11
# f 34 = 1.1435094428154562e-11
# f 35 = 5.717547214011901e-12
# f 36 = 2.858773606989605e-12
# f 37 = 1.4293868034907161e-12
# f 38 = 7.146934017443365e-13
# f 39 = 3.573467008719129e-13
# f 40 = 1.7867335043589258e-13
# f 41 = 8.933667521793034e-14
# f 42 = 4.466833760896117e-14
# f 43 = 2.233416880447959e-14
# f 44 = 1.1167084402239545e-14
# f 45 = 5.58354220111971e-15
# f 46 = 2.7917711005598398e-15
# f 47 = 1.395885550279916e-15
# f 48 = 6.97942775139957e-16
# f 49 = 3.4897138756997825e-16
# f 50 = 1.7448569378498908e-16
# f 51 = 8.724284689249451e-17
# f 52 = 4.362142344624725e-17
# f 53 = 2.1810711723123625e-17
# f 54 = 1.0905355861561813e-17
# f 55 = 5.452677930780906e-18
# f 56 = 2.726338965390453e-18
# f 57 = 1.3631694826952266e-18
# f 58 = 6.815847413476133e-19
# f 59 = 3.4079237067380664e-19
# f 60 = 1.7039618533690332e-19
# f 61 = 8.519809266845166e-20
# f 62 = 4.259904633422583e-20
# f 63 = 2.1299523167112915e-20
# f 64 = 1.0649761583556458e-20
# f 65 = 5.324880791778229e-21
# f 66 = 2.6624403958891144e-21
# f 67 = 1.3312201979445572e-21
# f 68 = 6.656100989722786e-22
# f 69 = 3.328050494861393e-22
# f 70 = 1.6640252474306965e-22
# f 71 = 8.320126237153482e-23
# f 72 = 4.160063118576741e-23
# f 73 = 2.0800315592883706e-23
# f 74 = 1.0400157796441853e-23
# f 75 = 5.2000788982209266e-24
# f 76 = 2.6000394491104633e-24
# f 77 = 1.3000197245552316e-24
# f 78 = 6.500098622776158e-25
# f 79 = 3.250049311388079e-25
# f 80 = 1.6250246556940395e-25
# f 81 = 8.125123278470198e-26
# f 82 = 4.062561639235099e-26
# f 83 = 2.0312808196175494e-26
# f 84 = 1.0156404098087747e-26
# f 85 = 5.0782020490438736e-27
# f 86 = 2.5391010245219368e-27
# f 87 = 1.2695505122609684e-27
# f 88 = 6.347752561304842e-28
# f 89 = 3.173876280652421e-28
# f 90 = 1.5869381403262105e-28
# f 91 = 7.934690701631052e-29
# f 92 = 3.967345350815526e-29
# f 93 = 1.983672675407763e-29
# f 94 = 9.918363377038816e-30
# f 95 = 4.959181688519408e-30
# f 96 = 2.479590844259704e-30
# f 97 = 1.239795422129852e-30
# f 98 = 6.19897711064926e-31
# f 99 = 3.09948855532463e-31
# f 100 = 1.549744277662315e-31
# f 1 = 0.2375
# f 2 = 0.17203906249999998
# f 3 = 0.135319542300415
# f 4 = 0.11115775558342016
# f 5 = 0.09386162350922293
# f 6 = 0.08079903818436403
# f 7 = 0.07055702593220342
# f 8 = 0.062299795422615496
# f 9 = 0.05549760436726996
# f 10 = 0.04979673926292574
# f 11 = 0.04495117282062064
# f 12 = 0.04078403663853777
# f 13 = 0.03716466404430396
# f 14 = 0.03399427920123908
# f 15 = 0.031196734773685918
# f 16 = 0.028712323587488903
# f 17 = 0.02649352975861142
# f 18 = 0.02450204150756394
# f 19 = 0.022706606896049274
# f 20 = 0.021081466054351683
# f 21 = 0.019605185951183355
# f 22 = 0.018259781503252734
# f 23 = 0.017030043788570894
# f 24 = 0.01590302032727374
# f 25 = 0.014867608558156855
# f 26 = 0.013914234635222362
# f 27 = 0.013034597274251422
# f 28 = 0.012221461720742025
# f 29 = 0.011468492714442939
# f 30 = 0.010770118069836621
# f 31 = 0.01012141649526848
# f 32 = 0.009518024752227898
# f 33 = 0.008956060359191682
# f 34 = 0.008432056874932486
# f 35 = 0.00794290942720087
# f 36 = 0.007485828636180546
# f 37 = 0.007058301455519771
# f 38 = 0.006658057744278639
# f 39 = 0.006283041610784866
# f 40 = 0.005931386748956911
# f 41 = 0.005601395130181649
# f 42 = 0.005291518527638365
# f 43 = 0.005000342441344523
# f 44 = 0.004726572065973121
# f 45 = 0.0044690200033543695
# f 46 = 0.004226595470385788
# f 47 = 0.003998294793059727
# f 48 = 0.003783193010217142
# f 49 = 0.0035804364378213566
# f 50 = 0.003389236067099274
# f 51 = 0.0032088616886817097
# f 52 = 0.003038636650577389
# f 53 = 0.002877933170988999
# f 54 = 0.0027261681380697043
# f 55 = 0.002582799338085044
# f 56 = 0.00244732206138102
# f 57 = 0.002319266042303453
# f 58 = 0.002198192694962047
# f 59 = 0.002083692611645969
# f 60 = 0.0019753832949088337
# f 61 = 0.0018729070979596773
# f 62 = 0.001775929351113985
# f 63 = 0.0016841366547511447
# f 64 = 0.001597235321555305
# f 65 = 0.001514949952838737
# f 66 = 0.0014370221355051742
# f 67 = 0.00136320924774288
# f 68 = 0.0012932833628752608
# f 69 = 0.0012270302419676422
# f 70 = 0.0011642484068152918
# f 71 = 0.001104748285839394
# f 72 = 0.0010483514262111125
# f 73 = 0.00099488976622336
# f 74 = 0.0009442049625476028
# f 75 = 0.0008961477675594881
# f 76 = 0.0008505774524012769
# f 77 = 0.0008073612718788062
# f 78 = 0.0007663739676727025
# f 79 = 0.0007274973066836572
# f 80 = 0.0006906196516348039
# f 81 = 0.0006556355613250008
# f 82 = 0.0006224454181689406
# f 83 = 0.000590955080876824
# f 84 = 0.0005610755603207493
# f 85 = 0.0005327227168095421
# f 86 = 0.0005058169771507103
# f 87 = 0.0004802830700195195
# f 88 = 0.0004560497782825635
# f 89 = 0.00043304970703817727
# f 90 = 0.0004112190662399408
# f 91 = 0.0003904974668635264
# f 92 = 0.0003708277296623046
# f 93 = 0.00035215570563435714
# f 94 = 0.000334430107393679
# f 95 = 0.0003176023507021003
# f 96 = 0.0003016264054764823
# f 97 = 0.00028645865563860153
# f 98 = 0.0002720577672233507
# f 99 = 0.0002583845642049119
# f 100 = 0.00024540191154079794
# f 1 = 0.5
# f 2 = 0.5
# f 3 = 0.5
# f 4 = 0.5
# f 5 = 0.5
# f 6 = 0.5
# f 7 = 0.5
# f 8 = 0.5
# f 9 = 0.5
# f 10 = 0.5
# f 11 = 0.5
# f 12 = 0.5
# f 13 = 0.5
# f 14 = 0.5
# f 15 = 0.5
# f 16 = 0.5
# f 17 = 0.5
# f 18 = 0.5
# f 19 = 0.5
# f 20 = 0.5
# f 21 = 0.5
# f 22 = 0.5
# f 23 = 0.5
# f 24 = 0.5
# f 25 = 0.5
# f 26 = 0.5
# f 27 = 0.5
# f 28 = 0.5
# f 29 = 0.5
# f 30 = 0.5
# f 31 = 0.5
# f 32 = 0.5
# f 33 = 0.5
# f 34 = 0.5
# f 35 = 0.5
# f 36 = 0.5
# f 37 = 0.5
# f 38 = 0.5
# f 39 = 0.5
# f 40 = 0.5
# f 41 = 0.5
# f 42 = 0.5
# f 43 = 0.5
# f 44 = 0.5
# f 45 = 0.5
# f 46 = 0.5
# f 47 = 0.5
# f 48 = 0.5
# f 49 = 0.5
# f 50 = 0.5
# f 51 = 0.5
# f 52 = 0.5
# f 53 = 0.5
# f 54 = 0.5
# f 55 = 0.5
# f 56 = 0.5
# f 57 = 0.5
# f 58 = 0.5
# f 59 = 0.5
# f 60 = 0.5
# f 61 = 0.5
# f 62 = 0.5
# f 63 = 0.5
# f 64 = 0.5
# f 65 = 0.5
# f 66 = 0.5
# f 67 = 0.5
# f 68 = 0.5
# f 69 = 0.5
# f 70 = 0.5
# f 71 = 0.5
# f 72 = 0.5
# f 73 = 0.5
# f 74 = 0.5
# f 75 = 0.5
# f 76 = 0.5
# f 77 = 0.5
# f 78 = 0.5
# f 79 = 0.5
# f 80 = 0.5
# f 81 = 0.5
# f 82 = 0.5
# f 83 = 0.5
# f 84 = 0.5
# f 85 = 0.5
# f 86 = 0.5
# f 87 = 0.5
# f 88 = 0.5
# f 89 = 0.5
# f 90 = 0.5
# f 91 = 0.5
# f 92 = 0.5
# f 93 = 0.5
# f 94 = 0.5
# f 95 = 0.5
# f 96 = 0.5
# f 97 = 0.5
# f 98 = 0.5
# f 99 = 0.5
# f 100 = 0.5
# f 1 = 0.8
# f 2 = 0.512
# f 3 = 0.7995392
# f 4 = 0.512884056522752
# f 5 = 0.7994688034800593
# f 6 = 0.5130189943751092
# f 7 = 0.7994576185134749
# f 8 = 0.5130404310855622
# f 9 = 0.7994558309027286
# f 10 = 0.5130438570827405
# f 11 = 0.7994555449356961
# f 12 = 0.5130444051432489
# f 13 = 0.7994554991822682
# f 14 = 0.5130444928303954
# f 15 = 0.7994554918617529
# f 16 = 0.5130445068602741
# f 17 = 0.7994554906904713
# f 18 = 0.5130445091050531
# f 19 = 0.7994554905030663
# f 20 = 0.5130445094642175
# f 21 = 0.7994554904730814
# f 22 = 0.5130445095216841
# f 23 = 0.7994554904682839
# f 24 = 0.5130445095308785
# f 25 = 0.7994554904675163
# f 26 = 0.5130445095323497
# f 27 = 0.7994554904673934
# f 28 = 0.5130445095325852
# f 29 = 0.7994554904673739
# f 30 = 0.5130445095326227
# f 31 = 0.7994554904673707
# f 32 = 0.5130445095326286
# f 33 = 0.7994554904673701
# f 34 = 0.5130445095326298
# f 35 = 0.7994554904673701
# f 36 = 0.5130445095326298
# f 37 = 0.7994554904673701
# f 38 = 0.5130445095326298
# f 39 = 0.7994554904673701
# f 40 = 0.5130445095326298
# f 41 = 0.7994554904673701
# f 42 = 0.5130445095326298
# f 43 = 0.7994554904673701
# f 44 = 0.5130445095326298
# f 45 = 0.7994554904673701
# f 46 = 0.5130445095326298
# f 47 = 0.7994554904673701
# f 48 = 0.5130445095326298
# f 49 = 0.7994554904673701
# f 50 = 0.5130445095326298
# f 51 = 0.7994554904673701
# f 52 = 0.5130445095326298
# f 53 = 0.7994554904673701
# f 54 = 0.5130445095326298
# f 55 = 0.7994554904673701
# f 56 = 0.5130445095326298
# f 57 = 0.7994554904673701
# f 58 = 0.5130445095326298
# f 59 = 0.7994554904673701
# f 60 = 0.5130445095326298
# f 61 = 0.7994554904673701
# f 62 = 0.5130445095326298
# f 63 = 0.7994554904673701
# f 64 = 0.5130445095326298
# f 65 = 0.7994554904673701
# f 66 = 0.5130445095326298
# f 67 = 0.7994554904673701
# f 68 = 0.5130445095326298
# f 69 = 0.7994554904673701
# f 70 = 0.5130445095326298
# f 71 = 0.7994554904673701
# f 72 = 0.5130445095326298
# f 73 = 0.7994554904673701
# f 74 = 0.5130445095326298
# f 75 = 0.7994554904673701
# f 76 = 0.5130445095326298
# f 77 = 0.7994554904673701
# f 78 = 0.5130445095326298
# f 79 = 0.7994554904673701
# f 80 = 0.5130445095326298
# f 81 = 0.7994554904673701
# f 82 = 0.5130445095326298
# f 83 = 0.7994554904673701
# f 84 = 0.5130445095326298
# f 85 = 0.7994554904673701
# f 86 = 0.5130445095326298
# f 87 = 0.7994554904673701
# f 88 = 0.5130445095326298
# f 89 = 0.7994554904673701
# f 90 = 0.5130445095326298
# f 91 = 0.7994554904673701
# f 92 = 0.5130445095326298
# f 93 = 0.7994554904673701
# f 94 = 0.5130445095326298
# f 95 = 0.7994554904673701
# f 96 = 0.5130445095326298
# f 97 = 0.7994554904673701
# f 98 = 0.5130445095326298
# f 99 = 0.7994554904673701
# f 100 = 0.5130445095326298
# f 1 = 0.95
# f 2 = 0.18050000000000016
# f 3 = 0.5620950500000005
# f 4 = 0.9353479781088904
# f 5 = 0.22979412423470422
# f 6 = 0.6725573818672562
# f 7 = 0.8368510098598481
# f 8 = 0.5188193091943221
# f 9 = 0.9486541676855043
# f 10 = 0.1850958637100242
# f 11 = 0.5731744628003645
# f 12 = 0.9296528923767365
# f 13 = 0.2485138898747569
# f 14 = 0.7096679983734816
# f 15 = 0.7829494557406192
# f 16 = 0.6457705008851319
# f 17 = 0.8692536520724515
# f 18 = 0.43187661363839625
# f 19 = 0.932364976076385
# f 20 = 0.23963000435737464
# f 21 = 0.6923883684024251
# f 22 = 0.8093495196731204
# f 23 = 0.5863509237764368
# f 24 = 0.9216653682592327
# f 25 = 0.2743536054010614
# f 26 = 0.7565180774971003
# f 27 = 0.6999542084853282
# f 28 = 0.7980695951342224
# f 29 = 0.6123871625347789
# f 30 = 0.9020026776500485
# f 31 = 0.3358966192163266
# f 32 = 0.8476663055784008
# f 33 = 0.4906869318687708
# f 34 = 0.9496704136955357
# f 35 = 0.18162677237816585
# f 36 = 0.5648262541478919
# f 37 = 0.9340307157379811
# f 38 = 0.23414588362470812
# f 39 = 0.6814220374639884
# f 40 = 0.8249269684251775
# f 41 = 0.5488053677220899
# f 42 = 0.940948537109744
# f 43 = 0.21114467295895145
# f 44 = 0.6329378801520338
# f 45 = 0.8828445760785973
# f 46 = 0.3930341161553565
# f 47 = 0.90652153883467
# f 48 = 0.32201290616126915
# f 49 = 0.8296182588220027
# f 50 = 0.5371368531143748
# f 51 = 0.9447592457348931
# f 52 = 0.19831901066665003
# f 53 = 0.6041566065644344
# f 54 = 0.9087753249741302
# f 55 = 0.31503038803071826
# f 56 = 0.8199877220621468
# f 57 = 0.5609098593720175
# f 58 = 0.9359019583188679
# f 59 = 0.22796003438834858
# f 60 = 0.6687781770180438
# f 61 = 0.8417529224573704
# f 62 = 0.5061787719690168
# f 63 = 0.9498549265524285
# f 64 = 0.18099607121473468
# f 65 = 0.5632986749943484
# f 66 = 0.9347744554270475
# f 67 = 0.23169045705083424
# f 68 = 0.6764379588171572
# f 69 = 0.8317046574160535
# f 70 = 0.5318936769442946
# f 71 = 0.9461346148096973
# f 72 = 0.1936628407806915
# f 73 = 0.5933986705494873
# f 74 = 0.9168514156904357
# f 75 = 0.28969260950014236
# f 76 = 0.7819290457043333
# f 77 = 0.6479608501153269
# f 78 = 0.8668088299659691
# f 79 = 0.43871487258418773
# f 80 = 0.935727705998985
# f 81 = 0.22853719165447586
# f 82 = 0.6699701860036127
# f 83 = 0.8402185163056098
# f 84 = 0.510155172418676
# f 85 = 0.9496081153979583
# f 86 = 0.18183966175952557
# f 87 = 0.5653411968486862
# f 88 = 0.9337760063786485
# f 89 = 0.23498582990272446
# f 90 = 0.6831164606610788
# f 91 = 0.8225797749728464
# f 92 = 0.5545806973581775
# f 93 = 0.9386796004084011
# f 94 = 0.21872879110499685
# f 95 = 0.6493687267776252
# f 96 = 0.8652181371511583
# f 97 = 0.4431397067241835
# f 98 = 0.9377142467846348
# f 99 = 0.2219437050146874
# f 100 = 0.6562018479123551
# f 1 = 0.9499962
# f 2 = 0.18051299594512815
# f 3 = 0.5621266061121607
# f 4 = 0.9353330822893409
# f 5 = 0.22984340836495548
# f 6 = 0.672658580785316
# f 7 = 0.8367182550285618
# f 8 = 0.5191591035759776
# f 9 = 0.9486051292506268
# f 10 = 0.18526306443810803
# f 11 = 0.5735745132938159
# f 12 = 0.9294298057755966
# f 13 = 0.2492421592638267
# f 14 = 0.7110579201754613
# f 15 = 0.7807273064585927
# f 16 = 0.6505302817523129
# f 17 = 0.8638944102471634
# f 18 = 0.4468072611253027
# f 19 = 0.9392480236178316
# f 20 = 0.21683246024174982
# f 21 = 0.6453013488235873
# f 22 = 0.8697725685141756
# f 23 = 0.43041934078283134
# f 24 = 0.931602421079036
# f 25 = 0.24213353045111505
# f 26 = 0.6973185587530971
# f 27 = 0.8020484682120821
# f 28 = 0.6033135468327924
# f 29 = 0.909439981955148
# f 30 = 0.3129638244709588
# f 31 = 0.8170663823651848
# f 32 = 0.5679818548606468
# f 33 = 0.9324381761568826
# f 34 = 0.239389450448014
# f 35 = 0.691912137556405
# f 36 = 0.8100449795424196
# f 37 = 0.5847140205100543
# f 38 = 0.9227294319702839
# f 39 = 0.27093934391510827
# f 40 = 0.750618620169044
# f 41 = 0.7113231674533448
# f 42 = 0.7803015718104452
# f 43 = 0.6514379095942564
# f 44 = 0.8628529262433429
# f 45 = 0.4496834648832441
# f 46 = 0.940379335916608
# f 47 = 0.21305095389105969
# f 48 = 0.6371089307612432
# f 49 = 0.8785643362009328
# f 50 = 0.40541836475563914
# f 51 = 0.9160063942431101
# f 52 = 0.2923669838056148
# f 53 = 0.7861764162268842
# f 54 = 0.6387916234230412
# f 55 = 0.8768001640168674
# f 56 = 0.4104822183080748
# f 57 = 0.919548953691636
# f 58 = 0.2811189667337631
# f 59 = 0.7679461544499571
# f 60 = 0.677178461598823
# f 61 = 0.8307096124328026
# f 62 = 0.5343983785292729
# f 63 = 0.9455036559073161
# f 64 = 0.1958006717782196
# f 65 = 0.5983585210957866
# f 66 = 0.9132372850458288
# f 67 = 0.30109279574221925
# f 68 = 0.7996565115585432
# f 69 = 0.6087827053061456
# f 70 = 0.9050320274998498
# f 71 = 0.3266064154575715
# f 72 = 0.8357517263902052
# f 73 = 0.5216289572587877
# f 74 = 0.9482223151900105
# f 75 = 0.186567673429686
# f 76 = 0.5766886713107362
# f 77 = 0.9276516212318566
# f 78 = 0.2550335452595056
# f 79 = 0.7219674569971185
# f 80 = 0.7627757025300829
# f 81 = 0.6876059346073213
# f 82 = 0.8162552505404311
# f 83 = 0.5699339427213147
# f 84 = 0.9314151258907172
# f 85 = 0.24274775878024726
# f 86 = 0.6985208806721738
# f 87 = 0.8002399477611492
# f 88 = 0.6074527003198532
# f 89 = 0.9061248853370929
# f 90 = 0.3232377945377459
# f 91 = 0.8312694663364555
# f 92 = 0.5329900545580079
# f 93 = 0.9458642939409866
# f 94 = 0.19457911927632093
# f 95 = 0.5955287253482944
# f 96 = 0.9153221980066545
# f 97 = 0.29452839300310085
# f 98 = 0.789569391128825
# f 99 = 0.63136835734087
# f 100 = 0.8844209478203335

# %%
def LogisticMap(r,f):
    x, y = [], []
    for i in range(100):
        f = r*f*(1-f)
        x.append(f)
        y.append(i)
        plt.plot(y, x, linewidth=1, color='black')

# %%
LogisticMap(0.5,0.5)

# %%
LogisticMap(0.95,0.5)

# %%
LogisticMap(2,0.5)

# %%
LogisticMap(3.2,0.5)

# %%
LogisticMap(3.8,0.5)

# %%
LogisticMap(3.8,0.501)

# %% [markdown]
# # 3. sinc function
# 싱크 함수를 그려보아라. 싱크함수는 다음처럼 주어진다.$$ sinc(x)  = \frac{\sin x}{x}. $$
# 싱크 함수를 테일러 전개하면 다음과 같다.$$ sinc(x)  = \frac{sin x}{x} = \sum_{n=0}^{\infty} \frac{(-1)^n x^{2n} }{(2n+1)!}. $$위의 식의 우변을 $n$을 바꾸어 가면서 그래프로 그리고 싱크함수와 비교하여라.

# %%
a=np.arange(-20,20,0.0001)
b=[np.sin(x)/x for x in a]
plt.plot(a,b,linewidth=2)

# %%
def s(x,n):
    f = 0
    for i in range(n+1):
        f = f + ((-1)**i*x**(2*i))/(math.factorial(2*i+1))
    return f

x = np.arange(-20,20,0.1)
plt.plot(x, s(x,1), color='grey',linewidth=2)
plt.plot(x, s(x,4), color='blue',linewidth=2)
plt.plot(x, s(x,9), color='black',linewidth=2)
plt.plot(x, s(x,16), color='red',linewidth=2)
plt.plot(x, s(x,25), color='yellow',linewidth=2)
plt.axis([-20, 20, -2, 2])
# Out:
# (-20.0, 20.0, -2.0, 2.0)

# %% [markdown]
# n이 증가할 수록 $$ sinc(x)  = \frac{\sin x}{x}. $$ 의 그래프와 같아진다
